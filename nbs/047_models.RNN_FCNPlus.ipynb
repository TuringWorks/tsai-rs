# %%
#|default_exp models.RNN_FCNPlus

# %% [markdown]
# # RNN-FCNPlus> Enhanced RNN-FCN

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## OverviewRNN-FCNPlus model for time series classification/regression.

# %%
# Load sample dataX_train, y_train, X_test, y_test = tsai_rs.get_UCR_data('ECG200')X_train = tsai_rs.ts_standardize(X_train)print(f"Data shape: {X_train.shape}")print(f"Classes: {len(np.unique(y_train))}")

# %% [markdown]
# ## Notetsai_rs provides high-performance Rust implementations of key models.For this specific architecture, use the appropriate config class.
