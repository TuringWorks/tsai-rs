# %%
#|default_exp models.multimodal

# %% [markdown]
# # Multimodal Models> Multimodal time series

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## OverviewMultimodal time series implemented in Rust for high performance.

# %%
# Example usage with tsai_rsX_train, y_train, _, _ = tsai_rs.get_UCR_data('ECG200')X_train = tsai_rs.ts_standardize(X_train)print(f"Data shape: {X_train.shape}")
