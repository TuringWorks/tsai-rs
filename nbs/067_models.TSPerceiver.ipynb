# %%
#|default_exp models.TSPerceiver

# %% [markdown]
# # TSPerceiver> Perceiver for time series

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## OverviewPerceiver for time series for time series with tsai_rs.

# %%
# Load sample dataX_train, y_train, X_test, y_test = tsai_rs.get_UCR_data('ECG200')X_train = tsai_rs.ts_standardize(X_train)print(f"Data ready: {X_train.shape}")
