# %%
#|default_exp models.utils

# %% [markdown]
# # Model Utilities> Model Utilities for time series models

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## Model UtilitiesImplemented in Rust for high performance.
