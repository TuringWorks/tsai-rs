# %%
#|default_exp models.TST

# %% [markdown]
# # TST (Time Series Transformer)> Transformer Architecture for Time Series

# %% [markdown]
# Based on:Zerveas, G., et al. (2021). **A Transformer-based Framework for Multivariate Time Series Representation Learning**. KDD 2021.Paper: https://dl.acm.org/doi/abs/10.1145/3447548.3467401

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## ArchitectureTST consists of:1. Input embedding layer2. Positional encoding3. Transformer encoder blocks4. Output head (classification/regression)

# %%
# Load sample dataX_train, y_train, X_test, y_test = tsai_rs.get_UCR_data('ECG200')X_train = tsai_rs.ts_standardize(X_train)# TST configurationconfig = tsai_rs.TSTConfig(    c_in=X_train.shape[1],    c_out=len(np.unique(y_train)),    seq_len=X_train.shape[2],    n_heads=4,    d_model=64,    d_ff=128,    n_layers=2,    dropout=0.1)print(f"TST configuration:")print(f"  d_model: {config.d_model}")print(f"  n_heads: {config.n_heads}")print(f"  n_layers: {config.n_layers}")
