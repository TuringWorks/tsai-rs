# %%
#|default_exp optimizer

# %% [markdown]
# # Optimizer> Optimizer configurations

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## Supported Optimizers

# %%
# Optimizer configurations available in tsai_rsOPTIMIZERS = {    'SGD': {'lr': 0.01, 'momentum': 0.9},    'Adam': {'lr': 0.001, 'betas': (0.9, 0.999)},    'AdamW': {'lr': 0.001, 'betas': (0.9, 0.999), 'weight_decay': 0.01},    'RAdam': {'lr': 0.001, 'betas': (0.9, 0.999)}}for name, config in OPTIMIZERS.items():    print(f"{name}: {config}")
