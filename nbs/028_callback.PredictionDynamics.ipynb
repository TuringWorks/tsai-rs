# %%
#|default_exp callback.PredictionDynamics

# %% [markdown]
# # Predictiondynamics> Callback functionality for tsai_rs

# %%
import tsai_rsimport numpy as np

# %% [markdown]
# ## OverviewCallbacks allow customizing training behavior.

# %%
# Callbacks are implemented in Rust for performance# Python interface provides configuration optionsprint("Callbacks available in tsai_rs training")
